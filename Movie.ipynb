# %%
import pandas as pd
import numpy as np

# %%
credits=pd.read_csv('C:/Users/Pc solution & Laptop/Downloads/tmdb_5000_credits.csv')
movies=pd.read_csv('C:/Users/Pc solution & Laptop/Downloads/tmdb_5000_movies.csv')

# %%
movies.head()
# Out:
#       budget                                             genres  \
# 0  237000000  [{"id": 28, "name": "Action"}, {"id": 12, "nam...
# 1  300000000  [{"id": 12, "name": "Adventure"}, {"id": 14, "...
# 2  245000000  [{"id": 28, "name": "Action"}, {"id": 12, "nam...
# 3  250000000  [{"id": 28, "name": "Action"}, {"id": 80, "nam...
# 4  260000000  [{"id": 28, "name": "Action"}, {"id": 12, "nam...
#
#                                        homepage      id  \
# 0                   http://www.avatarmovie.com/   19995
# 1  http://disney.go.com/disneypictures/pirates/     285
# 2   http://www.sonypictures.com/movies/spectre/  206647
# 3            http://www.thedarkknightrises.com/   49026
# 4          http://movies.disney.com/john-carter   49529
#
#                                             keywords original_language  \
# 0  [{"id": 1463, "name": "culture clash"}, {"id":...                en
# 1  [{"id": 270, "name": "ocean"}, {"id": 726, "na...                en
# ...

# %%
credits.head()['cast']
# Out:
# 0    [{"cast_id": 242, "character": "Jake Sully", "...
# 1    [{"cast_id": 4, "character": "Captain Jack Spa...
# 2    [{"cast_id": 1, "character": "James Bond", "cr...
# 3    [{"cast_id": 2, "character": "Bruce Wayne / Ba...
# 4    [{"cast_id": 5, "character": "John Carter", "c...
# Name: cast, dtype: object

# %%
movies=pd.merge(movies,credits,left_on='title',right_on='title')

# %%
movies.shape
# Out:
# (4809, 23)

# %%
movies=movies[['movie_id','title','genres','overview','keywords','cast','crew']] #relevant columns

# %%
movies.head()
# Out:
#    movie_id                                     title  \
# 0     19995                                    Avatar
# 1       285  Pirates of the Caribbean: At World's End
# 2    206647                                   Spectre
# 3     49026                     The Dark Knight Rises
# 4     49529                               John Carter
#
#                                               genres  \
# 0  [{"id": 28, "name": "Action"}, {"id": 12, "nam...
# 1  [{"id": 12, "name": "Adventure"}, {"id": 14, "...
# 2  [{"id": 28, "name": "Action"}, {"id": 12, "nam...
# 3  [{"id": 28, "name": "Action"}, {"id": 80, "nam...
# 4  [{"id": 28, "name": "Action"}, {"id": 12, "nam...
#
#                                             overview  \
# 0  In the 22nd century, a paraplegic Marine is di...
# 1  Captain Barbossa, long believed to be dead, ha...
# 2  A cryptic message from Bond’s past sends him o...
# 3  Following the death of District Attorney Harve...
# ...

# %%
movies.isnull().sum()
# Out:
# movie_id    0
# title       0
# genres      0
# overview    3
# keywords    0
# cast        0
# crew        0
# dtype: int64

# %%
movies.dropna(inplace=True)

# %%
movies.isnull().sum()
# Out:
# movie_id    0
# title       0
# genres      0
# overview    0
# keywords    0
# cast        0
# crew        0
# dtype: int64

# %%
movies.duplicated().sum()
# Out:
# np.int64(0)

# %%
movies.iloc[0].genres
# Out:
# '[{"id": 28, "name": "Action"}, {"id": 12, "name": "Adventure"}, {"id": 14, "name": "Fantasy"}, {"id": 878, "name": "Science Fiction"}]'

# %%
def convert(obj):
    L=[]
    for i in ast.literal_eval(obj):
        L.append(i['name'])
    return L

# %%
#list is string so fnunction can not work so we convert it into integer
import ast

# %%
movies['genres']=movies['genres'].apply(convert)

# %%
movies['keywords']=movies['keywords'].apply(convert)

# %%
movies['cast'] #name from the list of dict
# Out:
# 0       [{"cast_id": 242, "character": "Jake Sully", "...
# 1       [{"cast_id": 4, "character": "Captain Jack Spa...
# 2       [{"cast_id": 1, "character": "James Bond", "cr...
# 3       [{"cast_id": 2, "character": "Bruce Wayne / Ba...
# 4       [{"cast_id": 5, "character": "John Carter", "c...
#                               ...
# 4804    [{"cast_id": 1, "character": "El Mariachi", "c...
# 4805    [{"cast_id": 1, "character": "Buzzy", "credit_...
# 4806    [{"cast_id": 8, "character": "Oliver O\u2019To...
# 4807    [{"cast_id": 3, "character": "Sam", "credit_id...
# 4808    [{"cast_id": 3, "character": "Herself", "credi...
# Name: cast, Length: 4806, dtype: object

# %%
def convert_cast(obj):
    L=[]
    counter=0
    for i in ast.literal_eval(obj):
        if counter!=3:
            L.append(i['name'])
            counter+=1
        else:
            break
        
    return L

# %%
movies['cast']=movies['cast'].apply(convert_cast)

# %%
def convert_crew(obj):
    L=[]
    for i in ast.literal_eval(obj):
        if i['job']=='Director':
            L.append(i['name'])
    return L

# %%
movies['crew']=movies['crew'].apply(convert_crew)

# %%
import nltk
from nltk.corpus import stopwords
stop_words=set(stopwords.words('english'))

# %%
def remove_stopwords(text):
    text=' '.join([word for word in text.split() if word not in stop_words])
    return text

# %%
from nltk.stem.porter import PorterStemmer
ps=PorterStemmer()

# %%
import re
def remove_special(text):
    cleaned = re.sub(r'[^A-Za-z0-9\s\.]', ' ', text)
    return cleaned

# %%
def convert_lower(text):
    return text.lower()

# %%
movies['overview']=movies['overview'].apply(convert_lower)

# %%
movies['overview']=movies['overview'].apply(remove_special)
movies['overview']
# Out:
# 0       in the 22nd century  a paraplegic marine is di...
# 1       captain barbossa  long believed to be dead  ha...
# 2       a cryptic message from bond s past sends him o...
# 3       following the death of district attorney harve...
# 4       john carter is a war weary  former military ca...
#                               ...
# 4804    el mariachi just wants to play his guitar and ...
# 4805    a newlywed couple s honeymoon is upended by th...
# 4806     signed  sealed  delivered  introduces a dedic...
# 4807    when ambitious new york attorney sam is sent t...
# 4808    ever since the second grade when he first saw ...
# Name: overview, Length: 4806, dtype: object

# %%
movies['overview']=movies['overview'].apply(remove_stopwords)
movies['overview']
# Out:
# 0       22nd century paraplegic marine dispatched moon...
# 1       captain barbossa long believed dead come back ...
# 2       cryptic message bond past sends trail uncover ...
# 3       following death district attorney harvey dent ...
# 4       john carter war weary former military captain ...
#                               ...
# 4804    el mariachi wants play guitar carry family tra...
# 4805    newlywed couple honeymoon upended arrivals res...
# 4806    signed sealed delivered introduces dedicated q...
# 4807    ambitious new york attorney sam sent shanghai ...
# 4808    ever since second grade first saw e.t. extrate...
# Name: overview, Length: 4806, dtype: object

# %%
from nltk.stem.porter import PorterStemmer
ps=PorterStemmer()

def remove_stem(text):
    if not isinstance(text, str):   # check if not a string
        text = str(text)
    words = nltk.word_tokenize(text)                  
    stemmed_words = [ps.stem(word) for word in words] 
    return stemmed_words

# %%
movies['overview']=movies['overview'].apply(remove_stem)

# %%
movies['overview']
# Out:
# 0       [22nd, centuri, parapleg, marin, dispatch, moo...
# 1       [captain, barbossa, long, believ, dead, come, ...
# 2       [cryptic, messag, bond, past, send, trail, unc...
# 3       [follow, death, district, attorney, harvey, de...
# 4       [john, carter, war, weari, former, militari, c...
#                               ...
# 4804    [el, mariachi, want, play, guitar, carri, fami...
# 4805    [newlyw, coupl, honeymoon, upend, arriv, respe...
# 4806    [sign, seal, deliv, introduc, dedic, quartet, ...
# 4807    [ambiti, new, york, attorney, sam, sent, shang...
# 4808    [ever, sinc, second, grade, first, saw, e.t, ....
# Name: overview, Length: 4806, dtype: object

# %%
movies.head()
# Out:
#    movie_id                                     title  \
# 0     19995                                    Avatar
# 1       285  Pirates of the Caribbean: At World's End
# 2    206647                                   Spectre
# 3     49026                     The Dark Knight Rises
# 4     49529                               John Carter
#
#                                           genres  \
# 0  [Action, Adventure, Fantasy, Science Fiction]
# 1                   [Adventure, Fantasy, Action]
# 2                     [Action, Adventure, Crime]
# 3               [Action, Crime, Drama, Thriller]
# 4           [Action, Adventure, Science Fiction]
#
#                                             overview  \
# 0  [22nd, centuri, parapleg, marin, dispatch, moo...
# 1  [captain, barbossa, long, believ, dead, come, ...
# 2  [cryptic, messag, bond, past, send, trail, unc...
# 3  [follow, death, district, attorney, harvey, de...
# 4  [john, carter, war, weari, former, militari, c...
#
# ...

# %%
movies['genres']=movies['genres'].apply(lambda x:[i.replace(" ","") for i in x])
movies['keywords']=movies['keywords'].apply(lambda x:[i.replace(" ","") for i in x])
movies['cast']=movies['cast'].apply(lambda x:[i.replace(" ","") for i in x])
movies['crew']=movies['crew'].apply(lambda x:[i.replace(" ","") for i in x])

# %%
movies.head()
# Out:
#    movie_id                                     title  \
# 0     19995                                    Avatar
# 1       285  Pirates of the Caribbean: At World's End
# 2    206647                                   Spectre
# 3     49026                     The Dark Knight Rises
# 4     49529                               John Carter
#
#                                          genres  \
# 0  [Action, Adventure, Fantasy, ScienceFiction]
# 1                  [Adventure, Fantasy, Action]
# 2                    [Action, Adventure, Crime]
# 3              [Action, Crime, Drama, Thriller]
# 4           [Action, Adventure, ScienceFiction]
#
#                                             overview  \
# 0  [22nd, centuri, parapleg, marin, dispatch, moo...
# 1  [captain, barbossa, long, believ, dead, come, ...
# 2  [cryptic, messag, bond, past, send, trail, unc...
# 3  [follow, death, district, attorney, harvey, de...
# 4  [john, carter, war, weari, former, militari, c...
#
# ...

# %%
movies['tag']=movies['overview'] + movies['keywords'] + movies['cast'] + movies['crew']

# %%
df=movies[['movie_id','title','tag']]

# %%
df.head()
# Out:
#    movie_id                                     title  \
# 0     19995                                    Avatar
# 1       285  Pirates of the Caribbean: At World's End
# 2    206647                                   Spectre
# 3     49026                     The Dark Knight Rises
# 4     49529                               John Carter
#
#                                                  tag
# 0  [22nd, centuri, parapleg, marin, dispatch, moo...
# 1  [captain, barbossa, long, believ, dead, come, ...
# 2  [cryptic, messag, bond, past, send, trail, unc...
# 3  [follow, death, district, attorney, harvey, de...
# 4  [john, carter, war, weari, former, militari, c...

# %%
df['tag']=df['tag'].apply(lambda x: " ".join(x))
# Out:
# C:\Users\Pc solution & Laptop\AppData\Local\Temp\ipykernel_10704\1816781096.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['tag']=df['tag'].apply(lambda x: " ".join(x))

# %%
df.head()
# Out:
#    movie_id                                     title  \
# 0     19995                                    Avatar
# 1       285  Pirates of the Caribbean: At World's End
# 2    206647                                   Spectre
# 3     49026                     The Dark Knight Rises
# 4     49529                               John Carter
#
#                                                  tag
# 0  22nd centuri parapleg marin dispatch moon pand...
# 1  captain barbossa long believ dead come back li...
# 2  cryptic messag bond past send trail uncov sini...
# 3  follow death district attorney harvey dent bat...
# 4  john carter war weari former militari captain ...

# %% [markdown]
# ![image.png](attachment:c5a4f45a-fe4f-4d33-bb2a-b9c840716f48.png)
#
# create the tags into vectors and draw them, and then we find the vectors that are closest to the one we wanna find recommendations of, each row will have frequency of most repeated keywords, thats how it will be able to make a vector, say there are 2 keywords only, we get 2D, then we draw it, and same w rest of the rows, the vector or row closest to that vector will be our recommendation.

# %%
from sklearn.feature_extraction.text import CountVectorizer #Count of each unique value
cv=CountVectorizer(max_features=5000,stop_words='english')#1000 most used words, affects accuracy

# %%
vector=cv.fit_transform(df['tag']).toarray() #its all vectors now.

# %%
cv.get_feature_names_out() #5000 most used keywords
# Out:
# array(['000', '007', '10', ..., 'zone', 'zoo', 'zooeydeschanel'],
#       shape=(5000,), dtype=object)

# %%
df['tag'][0]
# Out:
# '22nd centuri parapleg marin dispatch moon pandora uniqu mission becom torn follow order protect alien civil . cultureclash future spacewar spacecolony society spacetravel futuristic romance space alien tribe alienplanet cgi marine soldier battle loveaffair antiwar powerrelations mindandsoul 3d SamWorthington ZoeSaldana SigourneyWeaver JamesCameron'

# %%
from sklearn.neighbors import NearestNeighbors

model_knn = NearestNeighbors(metric='cosine', algorithm='brute')
model_knn.fit(vector)  # or embeddings if you're using SentenceTransformer

# Find nearest neighbors for a movie
# Out:
# NearestNeighbors(algorithm='brute', metric='cosine')

# %%
def recommend_movie(obj):
    movie_index = df[df['title'] == obj].index[0]
    distances, indices = model_knn.kneighbors(vectors[movie_index].reshape(1, -1), n_neighbors=6)

    for i in indices[0][1:]:
        print(df.iloc[i].title)

# %%
from sklearn.metrics.pairwise import cosine_similarity

# %%
similarity = cosine_similarity(vector)

# %%
def recommend(movie):
    index = new[new['title'] == movie].index[0]
    distances = sorted(list(enumerate(similarity[index])),reverse=True,key = lambda x: x[1])
    for i in distances[1:6]:
        print(new.iloc[i[0]].title)

# %%
import pickle

# %%
pickle.dump(df, open('movie_list.pkl', 'wb'))
pickle.dump(similarity,open('similarity.pkl','wb'))
